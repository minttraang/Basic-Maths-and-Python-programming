# %% [markdown]
# # **Code in class**

# %% [markdown]
# Install streamlit by "pip install streamlit" in the terminal

# %% [markdown]
# M1W4_4_Wed_Project 1.1_app.py

# %%
import streamlit as st

st.title("Mint trying to understand the coding world")

import time
# Out:
# 2026-08-05 22:44:29.232 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-05 22:44:29.277
# ...
#   command:
#
#     streamlit run /opt/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-08-05 22:44:29.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-05 22:44:29.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.header("Analyse texts")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 st.header("Analyse texts")
#
# NameError: name 'st' is not defined
